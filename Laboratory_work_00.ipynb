# %% [markdown]
# <h2 style="color:#F37726; text-align:center;">Welcome to the first laboratory work in this course</h2>
# <h4 style="color:#F37726; text-align:center;">This laboratory work is not graded, but mandatory</h4>

# %% [markdown]
# <span style="color:#616262; font-size:15px"><b>1. The goal of this laboratory class:</b></span>
# <span>Advancing the Jupyter notebook skills</span>
# <br/>
# <p>
# <span style="color:#616262; font-size:15px; "><b>2. Learning outcomes of this laboratory class:</b></span>
# <ul style="margin:0px 0px 0px 18px;">
#     <li>Learning Jupyter Notebook Basics</li>
#     <li>Practicing Jupyter Notebook advanced features</li>
#     <li>Learning Jupyter Notebook orginizing styles</li>
# </ul>
# </p>
# <p>
#  <span style="color:#616262; font-size:15px; "><b>3. Deadline:</b></span> By the end of the class you have to complete 80% of your laboratory task and pass the MCQ_post_lab quiz on DL.
# </p>
#
# Your task is to complete this laboratory work within 80 minutes and submit the .ipynb file to DL "Laboratory00".
# <br/>
# <b>Pay attention to the file name - your file should be named as "Laboratory_work_00_Yoursurname_YourName_yourgroup".</b> In case you didn't name your file properly (as showed before) <b>-5% penalty</b> will be applied.

# %% [markdown]
# Let's start...

# %% [markdown]
# <h4>What Is A Jupyter Notebook?</h4>

# %% [markdown]
# In this case, "notebook" or "notebook documents" denote documents that contain both code and rich text elements, such as figures, links, equations, ... Because of the mix of code and text elements, these documents are the ideal place to bring together an analysis description, and its results, as well as, they can be executed perform the data analysis in real time.
#
# The Jupyter Notebook App produces these documents.

# %% [markdown]
# For now, you should know that "Jupyter" is a loose acronym meaning Julia, Python, and R.
# <br/>These programming languages were the first target languages of the Jupyter application, but nowadays, the notebook technology also supports many other languages.

# %% [markdown]
# <strong>So...</strong>

# %% [markdown]
# As you just saw, the main components of the whole environment are, on the one hand, the notebooks themselves and the application. On the other hand, you also have a notebook kernel and a notebook dashboard.

# %% [markdown]
# <h4>What Is The Jupyter Notebook App? </h4>

# %% [markdown]
# As a server-client application, the Jupyter Notebook App allows you to edit and run your notebooks via a web browser. The application can be executed on a PC without Internet access, or it can be installed on a remote server, where you can access it through the Internet.
#
# Its two main components are the kernels and a dashboard.
#
# A kernel is a program that runs and introspects the user’s code. The Jupyter Notebook App has a kernel for Python code, but there are also kernels available for other programming languages.

# %% [markdown]
# <strong>And...</strong>

# %% [markdown]
# As a web application in which you can create and share documents that contain <b>live code, equations, visualizations as well as text, </b> the Jupyter Notebook is one of the ideal tools to help you to gain the data science skills you need.

# %% [markdown]
# Here, should be some history of Jupyter Notebook, but, you have <strong>to discover it by yourself. Remember</strong>, you will pass MCQ_post_laboratory, where you are going to definetly encounter questions about Jupyter Notebook history.

# %% [markdown]
# <h4>How To Install Jupyter Notebook</h4>

# %% [markdown]
# There are at least two ways <u>to install Jupyter Notebook on your laptop</u>. You don't need to install it on university facilities, as you have it already installed.

# %% [markdown]
# <strong>1st way:</strong> Running Jupyter Notebooks With The Anaconda Python Distribution
#     <br/>
# <p style="margin-left:60px;">The advantage of Anaconda is that you have access to over 720 packages that can easily be installed with Anaconda's conda, a package, dependency, and environment manager. You can follow the instructions for the installation of Anaconda here for Mac or Windows.  </p>
#
#
# <strong>2nd way:</strong> Running Jupyter Notebook The Pythonic Way: Pip
# <br/> <span style="margin-left:60px;">To use this way </span>
# <br/> <span style="margin-left:60px;">* first, install Python 3.7 on your laptop (for now some issues can be encountered with Python 3.8) [here](https://www.python.org/downloads/) </span>
# <br/> <span style="margin-left:60px;">* second, install PIP check out how from here -> [here](https://pip.pypa.io/en/latest/installing/) </span>
# <br/> <span style="margin-left:60px;">* third, open <b>cmd</b> and enter "pip install jupyter lab" and then "pip install jupyter notebook"</span>
# <br/> <span style="margin-left:60px;"><u>If you encounter any issues with this installation - search for the same issue on stackoverflow </u></span>
# <br/>
# <br/>
# Also, you can use Docker container, but the usage of this container is out of the course scope.

# %% [markdown]
# <b>So, by this moment I expect you to have working jupyter notebook, congratulations!</b>
# <br/>
# *To start your notebook, you simply need to run the following command on cmd "jupyter notebook"

# %% [markdown]
# <span style="color:#F37726;">When you work with Jupyter Notebook, keep in mind that each cell works independently - best thing about interpreter. So, if you have some code on let's say cell #5 and cells 1-4 contain related code snippets - you have to run all of them, before running cell #5.

# %% [markdown]
# In this section you will earn 80%. To upgrade your score - complete the last section.

# %% [markdown]
# ***

# %% [markdown]
# <h4 style="color:#133337">TASKS FOR BASIC 80%</h4>

# %% [markdown]
# <strong>Task 1 Cells, cells, cells:</strong>
# <br/>
# By now, you saw that each cell in Jupyter Notebook can be either code or markdown.
# <br/>

# %% [markdown]
# ![Markdown_combobox.png](attachment:Markdown_combobox.png)

# %% [markdown]
# <br/>
# You can use HTML to make your text more structured and  visually appealing.
# <br/>
# You can add, remove or edit the cells according to your needs. And don't forget to insert explanatory text or titles and subtitles to clarify your code! That's what makes a notebook a notebook in the end.

# %% [markdown]
# <b>Your task is to create several different cells, well, several cells with different content to be correct. </b>
# <br/>
# Use this tutorial to progress with your task -> [here](https://daringfireball.net/projects/markdown/basics) and [here]( https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html)
# <br/>
# But don't copy the examples(texts, images, links and etc.) -> use your own examples

# %%
# An example of code cell 
# To run this code hit the button Run or use shft+Enter combination
message = "Salem Alem"
print(message)
# Out:
# Salem Alem

# %%
7+7
# Out:
# 14

# %% [markdown]
# Welcome to the course
# <br/> Guys

# %%
#your cell with simple python code goes here
print("Hello, jupyter")
# Out:
# Hello, jupyter

# %%
#your cell with simple text goes here

# %% [markdown]
# any text

# %%
#your cell with a first level heading goes here (don't use html)

# %% [markdown]
# # Heading here

# %%
#your cell with a horizontal rule goes here

# %% [markdown]
# <hr>

# %% [markdown]
# <p style=" text-align:center;">Horizontal lines</p>

# %% [markdown]
# <hr>

# %%
#your cell with a link shorthand goes here

# %% [markdown]
# <a id = "division_ID">shorthand link</a>

# %%
#your cell with a blockquote goes here

# %% [markdown]
# >blockquote

# %%
#your cell with HTML goes here

# %% [markdown]
# <p> HTML task </p>

# %%
#your cell with an image goes here

# %% [markdown]
# <img src="https://avatanplus.com/files/resources/original/5995c934cfcd615df119f673.jpg"></img>

# %%
#your cell with LaTeX equations goes here

# %% [markdown]
# $$
# \frac{arg 1}{arg 2} \\
# x^2\\
# e^{i\pi}\\
# A_i\\
# B_{ij}\\
# \sqrt[n]{arg}
# $$

# %%
#your cell with video equations goes here

# %% [markdown]
# <iframe width="560" height="315" src="https://www.youtube.com/watch?v=L0MK7qz13bU" frameborder="0" allowfullscreen></iframe>

# %%
#your cell with different background color (my favorite is green)

# %% [markdown]
# <BR/>
# <strong>Task 2 My personilized Jupyter Notebook:</strong>
# <br/>
# From the previous task you have learned how to create different content on your Jupyter Notebook. Now, you will be able to create very informative notebooks for different subjects.
# <br/>
# <br/>
# <b>Your next task is to use Jupyter Notebook Themes - to see how you can personilize your notebook.
# <b/>

# %% [markdown]
# First, install Jupyter Themes - go to the cmd and use the following command
# <br/>
# ![image.png](attachment:image.png)

# %% [markdown]
# Second, get the list of available themes
# <br/>
# ![image.png](attachment:image.png)

# %% [markdown]
# And finally, use the theme
# <br/>
# ![image.png](attachment:image.png)

# %% [markdown]
# <strong>Awesome!</strong>
# <br/><br/>
# <strong>Now, find out which theme was implemented on the images below</strong>

# %% [markdown]
# ![Task01_02.png](attachment:Task01_02.png)

# %% [markdown]
# ![Task01_03.png](attachment:Task01_03.png)

# %% [markdown]
# <b>Your answers:</b>

# %% [markdown]
# <strong>You have applied themes - time to return default theme.</strong>
# <br/>
# How will you do it?

# %% [markdown]
# <b>Your answers:</b>

# %% [markdown]
# <br/>
# <strong>Task 3 Making Your Jupyter Notebook Magical:</strong>
# <br/>
# There are some predefined ‘magic functions’ that will make your work a lot more interactive.
#
# To see which magic commands you have available in your interpreter, you can simply run the following cell:
# <br/>*Don't forget to uncomment it*

# %% [markdown]
#  More details about magic functions you can find [here](https://ipython.readthedocs.io/en/stable/interactive/magics.html)

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %% [markdown]
# And you'll see a whole bunch of them appearing. You'll probably see some magics commands that you'll grasp, such as %save, %clear or %debug, but others will be less straightforward.
#
# If you're looking for more information on the magics commands or on functions, you can always use the ?, just like this:
# <br/>*Don't forget to uncomment it*

# %%
# %pwd
# Out:
# 'C:\\Users\\troum\\Desktop\\Data Science\\labs'

# %% [markdown]
# Stated differently, the magic commands are either line-oriented or cell-oriented. In the first case, the commands are prefixed <b>with the % </b> character and they work as follows: they get as an argument the rest of the line. When you want to pass not only the line but also the lines that follow, you need cell-oriented magic: then, the commands need to be prefixed <b>with %%.</b>

# %% [markdown]
# <b>Now, your task - discover what does this magic functions do:</b>
# <br/>
# %time, %%time, %timeit, %prun, %lprun, %mprun, %bash, %env, %who, %writefile, %pycat, %pbd, %run and %load.
# <br/>
# *Use each magic function in differnt cell, and save the output*

# %%
print("hello")
# %time
# Out:
# hello
# 32
# Wall time: 0 ns

# %%
# %timeit pass
# Out:
# 7.34 ns ± 0.707 ns per loop (mean ± std. dev. of 7 runs, 100000000 loops each)

# %%
# %prun

# %%
# %lprun
# Out:
# UsageError: Line magic function `%lprun` not found.

# %%
# %mprun
# Out:
# UsageError: Line magic function `%mprun` not found.

# %%
# %bash
# Out:
# UsageError: %%script is a cell magic, but the cell body is empty.

# %%
# %env
# Out:
# {'ALLUSERSPROFILE': 'C:\\ProgramData',
#  'APPDATA': 'C:\\Users\\troum\\AppData\\Roaming',
#  'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#  'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#  'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#  'COMPUTERNAME': 'LAPTOP-TOGKK6PS',
#  'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe',
#  'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#  'FPS_BROWSER_APP_PROFILE_STRING': 'Internet Explorer',
#  'FPS_BROWSER_USER_PROFILE_STRING': 'Default',
#  'HOMEDRIVE': 'C:',
#  'HOMEPATH': '\\Users\\troum',
#  'LOCALAPPDATA': 'C:\\Users\\troum\\AppData\\Local',
#  'LOGONSERVER': '\\\\LAPTOP-TOGKK6PS',
#  'NUMBER_OF_PROCESSORS': '8',
#  'ONEDRIVE': 'C:\\Users\\troum\\OneDrive',
#  'OS': 'Windows_NT',
# ...

# %%
# %who
# Out:
# x	 y

# %%
# %writefile [-a] tomiris.txt
# Out:
# UsageError: Line magic function `%writefile` not found (But cell magic `%%writefile` exists, did you mean that instead?).

# %%
# %pycat Laboratory_work_00.ipynb

# %%
# %pbd
# Out:
# UsageError: Line magic function `%pbd` not found.

# %%
# %load Laboratory_work_00.ipynb

# %% [markdown]
# <h4 style="color:#9d3133"> Now its high time to pass to MCQ_post_lab</h4>

# %% [markdown]
# <h4 style="color:#133337">Some extra tasks (sure, for extra points):</h4>

# %% [markdown]
# 1. Follow the provided link and/or convert your Jupyter Notebook into Pelican blog https://github.com/danielfrg/pelican-ipynb
# <br/>
# or
# 2. Follow the provided link and/or convert your Jupyter Notebook into Jupyter Dashboard https://jupyter-dashboards-layout.readthedocs.io/en/latest/getting-started.html
# <br/>
# or
# 3. Follow the provided link and/or convert your Jupyter Notebook into slides https://github.com/Anaconda-Platform/nbpresent
# <br/>
# or
# 4. Follow the provided link and/or convert your Jupyter Notebook into static web page https://github.com/jupyter/nbviewer
