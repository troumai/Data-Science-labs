# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# <h2 style="text-align:center;">Welcome to the third laboratory work in this course</h2>
# <h4 style="text-align:center;">This laboratory work is graded</h4>

# %% [markdown]
# <span style="color:#011f4b; font-size:15px"><b>The goal</b> of the laboratory work - is to get you familiar with matplotlib
# <br/>
# <b>Learning outcomes:</b>
# * to be able to use different visualization methods on data
# * to use matplotlib to investigate data
# </span>
# <br/><br/>
# <span style="color:#011f4b;">
# Your task is to complete this laboratory work within 80 minutes and submit the .ipynb file to DL "Laboratory03".
# <br/>
# <b>Pay attention to the file name - your file should be named as "Laboratory_work_03_Yoursurname_YourName_yourgroup".</b> In case you didn't name your file properly (as showed before) <b>-5% penalty</b> will be applied.
# </span>

# %% [markdown]
# <hr>

# %% [markdown]
# <span style="color:#011f4b">Humans are very visual creatures: <strong>we understand things better when we see things visualized</strong>. However, the step to presenting analyses, results or insights can be a bottleneck: you might not even know where to start or you might have already a right format in mind, but then questions like “Is this the right way to visualize the insights that I want to bring to my audience?” will have definitely come across your mind.

# %% [markdown]
# <span style="color:#011f4b; font-size:16px;"><b>What Does A Matplotlib Python Plot Look Like?</b></span>

# %% [markdown]
# <span style="color:#011f4b">To get started with <code><b>matplotlib</b></code> you don’t need much: you need to make the necessary imports, prepare some data, and you can start plotting with the help of the <code><b>plot()</b></code> function!
# <br/>When you’re ready, don’t forget to show your plot using the <code><b>show()</b></code> function.</span>

# %% [markdown]
# <span style="color:#09107d"><b>Example,</b></span>

# %%
# Import the necessary packages and modules
import matplotlib.pyplot as plt
import numpy as np

# Prepare the data
data = np.linspace(0, 9, 100)

# Plot the data
plt.plot(data, data, label='linear')
# Add label text
plt.ylabel('some numbers')
plt.xlabel('some numbers')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# <span style="color:#011f4b"><b> <b><span style="font-size:20px; color:orange">S</span>ee? </b>Great, isn’t it?
# <br/><br/>
# Now, let's go to practice </span>

# %% [markdown]
# <b>First things first,</b> import <code><b>matplotlib</b></code>, <code><b>pandas</b></code> and <code><b>numpy</b></code>packages to your notebook.
# <br/> Simply uncomment the cell below:

# %% [markdown]
# <p style="text-align:right; color:#1460AA;">+2
#     points </p>

# %%
# Uncomment and run this cell
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# <b>Inline</b> your matplotlib

# %%
#Uncomment and run this cell
# %matplotlib inline

# %% [markdown]
# <b>Why</b> you should inline the matplotlib?
# <br/> Your answer is:

# %% [markdown]
# %matplotlib inline sets the backend of matplotlib to the 'inline' backend
# When using the 'inline' backend, your matplotlib graphs will be included in your notebook, next to the code

# %% [markdown]
# <b><span style="font-size:20px; color:orange">G</span>reat!</b>
# <br/>
# <b>Now</b> let's start with tasks:
# <br/>

# %% [markdown]
# <h3>TASK 1: Data preparation </h3>

# %% [markdown]
# <b>Task 1.1 </b> Read Lemonade_new.csv to pandas dataframe, uncomment and run the cell below

# %% [markdown]
# <p style="text-align:right; color:#1460AA;">+3
#     points </p>

# %%
data = pd.read_csv('Lemonade_new.csv')
data.head()
# Out:
#          Date        Day  Temperature  Rainfall  Flyers  Price  Sales  Season  \
# 0  2017-01-01     Sunday         27.0      2.00      15    0.3     10  Winter
# 1  2017-01-02     Monday         28.9      1.33      15    0.3     13  Winter
# 2  2017-01-03    Tuesday         34.5      1.33      27    0.3     15  Winter
# 3  2017-01-04  Wednesday         44.1      1.05      28    0.3     17  Winter
# 4  2017-01-05   Thursday         42.4      1.00      33    0.3     18  Winter
#
#    Revenue
# 0      3.0
# 1      3.9
# 2      4.5
# 3      5.1
# 4      5.4

# %% [markdown]
# As you already saw, Lemonade_new.csv file contains more data than the dataset we used before.
# <br/><br/>
# Now, run the following 2 cells, and the location to your data will be added

# %%
# Run this cell
def location_setter():
    places = ['El Gotic', 'Raval', 'Sant Pere', 'Santa Caterina i la Ribera', 'La Barceloneta', 'La Texionera', 'Poblenou']
    for i in data.index:
        data.loc[i, 'Location'] = places[np.random.randint(0,7)]

# %%
# Run this cell
location_setter()

# %%
# Now check out what your data lookc like, what have changed?

# %%
# Your code goes here
data
# Out:
#            Date        Day  Temperature  Rainfall  Flyers  Price  Sales  \
# 0    2017-01-01     Sunday         27.0      2.00      15    0.3     10
# 1    2017-01-02     Monday         28.9      1.33      15    0.3     13
# 2    2017-01-03    Tuesday         34.5      1.33      27    0.3     15
# 3    2017-01-04  Wednesday         44.1      1.05      28    0.3     17
# 4    2017-01-05   Thursday         42.4      1.00      33    0.3     18
# ..          ...        ...          ...       ...     ...    ...    ...
# 360  2017-12-27  Wednesday         42.7      1.00      33    0.3     19
# 361  2017-12-28   Thursday         37.8      1.25      32    0.3     16
# 362  2017-12-29     Friday         39.5      1.25      17    0.3     15
# 363  2017-12-30   Saturday         30.9      1.43      22    0.3     13
# 364  2017-12-31     Sunday         15.1      2.50       9    0.3      7
#
#      Season  Revenue                    Location
# 0    Winter      3.0  Santa Caterina i la Ribera
# ...

# %% [markdown]
# <b>Awesome</b>, now you can perform some observation over your dataframe
# <br/>
# Your next tasks will focus on visualization

# %% [markdown]
# <h3>TASK 2: Creating graphs </h3>

# %% [markdown]
# <b>Task 2.1</b> Plotting bar charts
# <br/>
# On the example below, the bar chart for Seasons was plotted the documentation [here](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html)

# %%
plt.bar(data.Season.unique(), data.groupby('Season')['Sales'].sum(), width = 0.9, 
        color='#288664', ec='#288664')
plt.xlabel('Seasons')
plt.ylabel('Sales amount')
plt.title('Sales over seasons')
plt.show()

# %% [markdown]
# <b>Now, plot a bar char for Days and Revenue means </b>
# <br/>
# And write the summary below

# %% [markdown]
# <p style="text-align:right; color:#1460AA;">+5
#     points </p>

# %%
# Your code goes here
plt.bar(data.Day.unique(), data.groupby('Day')['Revenue'].mean(), width=0.5,
       color='#286886', ec='#286886')
plt.xticks(rotation=30)
plt.xlabel('Days')
plt.ylabel('Revenue')
plt.title('Days and Revenue')
plt.show()

# %% [markdown]
# We are visualizing data - to get some knowledge about it, so visualization without a summary is like the ski without snow.

# %% [markdown]
# <p style="text-align:right; color:#1460AA;">+5
#     points </p>

# %% [markdown]
# Presented graphs is not shows the day of the week, which has the most selled lemonade, but, it also shows the minimum of selled lemonade during the week

# %% [markdown]
# -----

# %% [markdown]
# <b>Task 2.2</b> Plotting bar charts
# <br/> Plot a bar chart visualizing <b>Locations and Sales </b>
# <br/>
# And write the summary below

# %% [markdown]
# <p style="text-align:right; color:#1460AA;">+10
#     points </p>

# %%
# Your code goes here
plt.bar(data.Location.unique(), data.groupby('Location')['Sales'].sum(), width=0.5,
       color='#632e99', ec='#632e99')
plt.xticks(rotation=30)
plt.xlabel('Location')
plt.ylabel('Sales')
plt.title('Location and Sales')
plt.show()

# %% [markdown]
# This graph describes amount of sales in different locations. The biggest sales were in the city Raval, the least sold in the city Sant Pere

# %% [markdown]
# <b>Task 2.3</b> Plotting bar charts
# <br/> Plot two bar charts visualizing <b>Any month days + Sales </b> and <b> June days + Sales</b>
# Use subplot, both graphs should be on the same figue
# <br/>
# And write the summary below

# %% [markdown]
# <p style="text-align:right; color:#1460AA;">+10
#     points </p>

# %%
# Your code goes here

# %%
data['Date']=pd.to_datetime(data['Date'])
data.Date
data['Month']=data['Date'].dt.month

# %%
plt.figure(figsize=(8,4))
plt.subplot(121)
plt.bar(data['Day'][data.Month==12].unique(),data[data.Month==12].groupby('Day',sort=False)['Sales'].sum(), width =0.5, 
        color='#632e99', ec='black')
plt.xticks(rotation = 90)
plt.subplot(122)
plt.bar(data['Day'][data.Month == 6].unique(),data[data.Month==6].groupby('Day',sort=False)['Sales'].sum(), width =0.5, 
        color='#992e84', ec='black')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Comparing these two charts, we can say that sales in June are 2 times higher than December ones.

# %% [markdown]
# <b>TASK 3</b> Scatterplots

# %% [markdown]
# Take a look at well known <u>Temperature - Sales relationship</u>, visualized by scatterplot

# %%
plt.scatter(data.Temperature, data.Sales, 50, marker = '*', color = '#86284a')
plt.yticks(np.arange(0, 60, 5))
plt.xticks(np.arange(10, 130, 10))
plt.xlabel('Temperature')
plt.ylabel('Sales')
plt.axis('equal')
plt.title('Sales and Temperature relationship')
plt.show()

# %% [markdown]
# <b> Task 3.1 </b> Create a scatterplot for <u>Revenue - Flyers </u>, use legend method of scatterplot
# <br/>
# And write the summary below

# %% [markdown]
# <p style="text-align:right; color:#1460AA;">+10
#     points </p>

# %%
# Your code goes here
plt.scatter(data.Flyers, data.Revenue, 50, marker = '*', color = '#86284a')
plt.yticks(np.arange(0, 30, 10))
plt.xticks(np.arange(0, 100, 10))
plt.xlabel('Revenue')
plt.ylabel('Flyers')
plt.axis('equal')
plt.title(' Revenue - Flyers  relationship')
plt.show()

# %% [markdown]
# The scatter chart does not show the relationship between revenue and flyers. Because revenue increases regardless of the number of flyers

# %% [markdown]
# <b>Task 3.2 </b> Create a scatterplot for <u> Any month's days - Sales </u>
# <br/>
# And write the summary below

# %% [markdown]
# <p style="text-align:right; color:#1460AA;">+12
#     points </p>

# %%
# Your code goes here
May= data[data.Date.dt.month==5]
plt.scatter(May.Date.dt.day, May.Sales, 50, marker = '.', color = '#632e99')
plt.yticks(np.arange(0, 50, 20))
plt.xticks(np.arange(0, 31, 1))
plt.xlabel('Date')
plt.ylabel('Sales')
plt.title('Date and Sales relationship')
plt.show()

# %%
# Your code goes here

# %%
# Turn this cell into markdown and write short summary here

# %% [markdown]
# -----

# %% [markdown]
# <b>Awesome, </b>now it's time to solve some task individually =)

# %% [markdown]
# <b>TASK 4</b> Histogram

# %% [markdown]
# <b>Task 4.1</b> Create a histogram chart for your dataset.
# <br/>
# And write the summary below

# %% [markdown]
# <p style="text-align:right; color:#1460AA;">+13
#     points </p>

# %%
# Your code goes here
plt.hist([data.Sales], ec='black')
plt.xlabel('Sales')
plt.show()

# %% [markdown]
# The sales histogram shows that sales are mostly average. On average, about 25-30 are sold

# %% [markdown]
# <b>Task 4.2</b> Create a scatter plot with histograms, you can use Sales - Temperature pair, or any other pair of data.
# <br/>
# And write the summary below [This link can be helpful](https://matplotlib.org/3.1.1/gallery/lines_bars_and_markers/scatter_hist.html#sphx-glr-gallery-lines-bars-and-markers-scatter-hist-py)

# %% [markdown]
# <p style="text-align:right; color:#1460AA;">+15
#     points </p>

# %%
# Your code goes here
import numpy as np
import matplotlib.pyplot as plt

x = data.Sales
y = data.Temperature

# definitions for the axes
left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
spacing = 0.005


rect_scatter = [left, bottom, width, height]
rect_histx = [left, bottom + height + spacing, width, 0.2]
rect_histy = [left + width + spacing, bottom, 0.2, height]

# start with a rectangular Figure
plt.figure(figsize=(8, 8))

ax_scatter = plt.axes(rect_scatter)
ax_scatter.tick_params(direction='in', top=True, right=True)
ax_histx = plt.axes(rect_histx)
ax_histx.tick_params(direction='in', labelbottom=False)
ax_histy = plt.axes(rect_histy)
ax_histy.tick_params(direction='in', labelleft=False)

# the scatter plot:
ax_scatter.scatter(x, y)

# now determine nice limits by hand:
binwidth = 0.25
lim = np.ceil(np.abs([x, y]).max() / binwidth) * binwidth
ax_scatter.set_xlim((-lim, lim))
ax_scatter.set_ylim((-lim, lim))

bins = np.arange(-lim, lim + binwidth, binwidth)
ax_histx.hist(x, bins=bins)
ax_histy.hist(y, bins=bins, orientation='horizontal')

ax_histx.set_xlim(ax_scatter.get_xlim())
ax_histy.set_ylim(ax_scatter.get_ylim())

plt.show()

# %%
# Your code goes here

# %% [markdown]
# <b>TASK 5</b> Pie chart

# %% [markdown]
# <b>Task 5.1</b> Create a pie chart for your dataset. Use anymonth's sales as part of the whole
# <br/>
# And write the summary below

# %% [markdown]
# <p style="text-align:right; color:#1460AA;">+15
#     points </p>

# %%
# Your code goes here
plt.pie(data.groupby('Season')['Sales'].sum(), labels=data.Season.unique())
plt.show()

# %% [markdown]
# One could say that sales increase in warmer seasons, but because in winter, sales are higher than in autumn, although it is a colder season. Therefore, there is no logical connection here

# %% [markdown]
# <b><span style="font-size:20px; color:orange">G</span>reat!</b> You did awesome job! <br/> <br/> But don't stop practicing, remember - you don't have to memorize everything about visualization with matplotlib.pyplot. <br/> The most important question here is - What are you visualizing and why?
# <br/> <br/> <b>Now</b> go to the Quiz 03
# <br/>

# %% [markdown]
# [Some useful tutorials](https://matplotlib.org/stable/tutorials/intermediate/gridspec.html#sphx-glr-tutorials-intermediate-gridspec-py)

# %% [markdown]
# Flayers&Rainfall

# %%
data.head()
# Out:
#         Date        Day  Temperature  Rainfall  Flyers  Price  Sales  Season  \
# 0 2017-01-01     Sunday         27.0      2.00      15    0.3     10  Winter
# 1 2017-01-02     Monday         28.9      1.33      15    0.3     13  Winter
# 2 2017-01-03    Tuesday         34.5      1.33      27    0.3     15  Winter
# 3 2017-01-04  Wednesday         44.1      1.05      28    0.3     17  Winter
# 4 2017-01-05   Thursday         42.4      1.00      33    0.3     18  Winter
#
#    Revenue                    Location  Month
# 0      3.0  Santa Caterina i la Ribera      1
# 1      3.9              La Barceloneta      1
# 2      4.5                   Sant Pere      1
# 3      5.1                La Texionera      1
# 4      5.4                   Sant Pere      1

# %%
import seaborn as sns

# %%
sns.scatterplot(x = "Flyers", y = "Rainfall", data = data)
